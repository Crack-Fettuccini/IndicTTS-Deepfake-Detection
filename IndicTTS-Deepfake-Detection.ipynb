# %%
# !pip install datasets librosa torchaudio transformers lightgbm xgboost scikit-learn numpy pandas tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 24.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.4 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import librosa
import librosa.display
import torchaudio
import torch
import matplotlib.pyplot as plt
from datasets import load_dataset
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_auc_score
from transformers import Wav2Vec2Model, Wav2Vec2FeatureExtractor
import lightgbm as lgb
import xgboost as xgb
from tqdm import tqdm
import os

# %%
dataset = load_dataset("SherryT997/IndicTTS-Deepfake-Challenge-Data")
train_data, test_data = dataset["train"], dataset["test"]
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/2.81k [00:00<?, ?B/s]
# ...
# Resolving data files:   0%|          | 0/35 [00:00<?, ?it/s]
# ...
# train-00000-of-00035.parquet:   0%|          | 0.00/453M [00:00<?, ?B/s]
# train-00001-of-00035.parquet:   0%|          | 0.00/461M [00:00<?, ?B/s]
# train-00002-of-00035.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# train-00003-of-00035.parquet:   0%|          | 0.00/443M [00:00<?, ?B/s]
# ...

# %%
print(dataset)
print(train_data.column_names)
print(train_data[0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'id', 'language', 'is_tts', 'audio'],
#         num_rows: 31102
#     })
#     test: Dataset({
#         features: ['text', 'id', 'language', 'is_tts', 'audio'],
#         num_rows: 2635
#     })
# })
# ['text', 'id', 'language', 'is_tts', 'audio']
# {'text': 'বিত্তীয় সময়সীমা মানি চলাত বাৰে বাৰে বিফল হোৱাৰ বাবে মই বৰ হতাশ হৈছোঁ।', 'id': 'ASM_F_ANGER_00342', 'language': 'Assamese', 'is_tts': 1, 'audio': {'path': 'ASM_F_ANGER_00342.wav', 'array': array([-0.00297868, -0.00474697, -0.00408163, ..., -0.00600238,
#        -0.00075703,  0.00277057]), 'sampling_rate': 16000}}

# %%
def extract_features(audio_array, sr):
    y = np.array(audio_array)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20).mean(axis=1)
    zcr = librosa.feature.zero_crossing_rate(y).mean()
    spec_centroid = librosa.feature.spectral_centroid(y=y, sr=sr).mean()
    return np.hstack([mfcc, zcr, spec_centroid])

# %%
import datasets
print(datasets.config.HF_DATASETS_CACHE)  # Shows the dataset cache location
# Out:
# /root/.cache/huggingface/datasets

# %%
# Process training data
X, y = [], []
for sample in tqdm(train_data, desc="Extracting Train Features"):
    X.append(extract_features(sample['audio']['array'], sample['audio']['sampling_rate']))
    y.append(sample['is_tts'])
X = np.array(X)
y = np.array(y)

# Process test data
X_test = []
ids = []
for sample in tqdm(test_data, desc="Extracting Test Features"):
    X_test.append(extract_features(sample['audio']['array'], sample['audio']['sampling_rate']))
    ids.append(sample['id'])
X_test = np.array(X_test)
# Out:
# Extracting Train Features:   9%|▊         | 2657/31102 [02:15<14:19, 33.10it/s]/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=929
#   warnings.warn(
# Extracting Train Features:   9%|▊         | 2675/31102 [02:16<11:55, 39.75it/s]/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=2044
#   warnings.warn(
# Extracting Train Features:  18%|█▊        | 5481/31102 [04:54<23:36, 18.09it/s]/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1672
#   warnings.warn(
# Extracting Train Features:  59%|█████▉    | 18382/31102 [16:25<09:06, 23.27it/s]/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=744
#   warnings.warn(
# ...

# %%
# LightGBM Model
lgb_model = lgb.LGBMClassifier(n_estimators=500, learning_rate=0.05, max_depth=7)
lgb_model.fit(X, y)
lgb_preds = lgb_model.predict_proba(X_test)[:, 1]

# XGBoost Model
xgb_model = xgb.XGBClassifier(n_estimators=500, learning_rate=0.05, max_depth=7, eval_metric='logloss')
xgb_model.fit(X, y)
xgb_preds = xgb_model.predict_proba(X_test)[:, 1]

# Wav2Vec2 Feature Extraction
feature_extractor = Wav2Vec2FeatureExtractor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h")

X_wav2vec = []
for sample in tqdm(test_data, desc="Extracting Wav2Vec2 Features"):
    waveform = torch.tensor(sample['audio']['array']).unsqueeze(0)
    inputs = feature_extractor(waveform.squeeze().numpy(), return_tensors="pt", sampling_rate=sample['audio']['sampling_rate'])
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state.mean(dim=1).squeeze().numpy()
    X_wav2vec.append(embeddings)
wav2vec_preds = np.array(X_wav2vec).mean(axis=1)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 15544, number of negative: 15558
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007939 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5610
# [LightGBM] [Info] Number of data points in the train set: 31102, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499775 -> initscore=-0.000900
# [LightGBM] [Info] Start training from score -0.000900
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/159 [00:00<?, ?B/s]
# ...

# %%
final_preds = (lgb_preds + xgb_preds + wav2vec_preds) / 3

stacked_X = np.vstack([lgb_preds, xgb_preds, wav2vec_preds]).T
meta_model = lgb.LGBMRegressor(n_estimators=100, learning_rate=0.05)
meta_model.fit(stacked_X, final_preds)
meta_preds = meta_model.predict(stacked_X)

submission = pd.DataFrame({"id": ids, "is_tts": meta_preds})
submission.to_csv("submission.csv", index=False)
print("Submission file saved: submission.csv")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000229 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 765
# [LightGBM] [Info] Number of data points in the train set: 2635, number of used features: 3
# [LightGBM] [Info] Start training from score 0.452651
# Submission file saved: submission.csv
